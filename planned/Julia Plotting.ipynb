# %%
using Plots

# %%
x = 1:10
y = rand(10)
plot(x, y)

# %%
x = 1:10
y = 1:10
z = Matrix{Float64}(undef, 10, 10)
for i in 1:10, j in 1:10
    z[i, j] = x[i]^2 + y[i]^2
end
surface(x, y, z)

# %%
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
x = 1:10
y = rand(10)
plot(x, y)

# %%
x = 1:10
y = 1:10
z = Matrix{Float64}(undef, 10, 10)
for i in 1:10, j in 1:10
    z[i, j] = x[i]^2 + y[i]^2
end
surface(x, y, z)
